# %%
import pandas as pd
import numpy as np
import os
os.path.join('C:', os.sep,'Users\Victoria\Desktop\DS\creditcard.csv', 'as')
a = pd.read_csv('C:\\Users\\Victoria\\Desktop\\DS\\creditcard.csv')
a.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
a.describe()
# Out:
#                 Time             V1            V2             V3  \
# count  284806.000000  284806.000000  2.848060e+05  284806.000000
# mean    94813.585781       0.000002  6.661837e-07      -0.000002
# std     47488.004530       1.958699  1.651311e+00       1.516257
# min         0.000000     -56.407510 -7.271573e+01     -48.325589
# 25%     54201.250000      -0.920374 -5.985522e-01      -0.890368
# 50%     84691.500000       0.018109  6.549621e-02       0.179846
# 75%    139320.000000       1.315645  8.037257e-01       1.027198
# max    172788.000000       2.454930  2.205773e+01       9.382558
#
#                   V4            V5             V6             V7  \
# count  284806.000000  2.848060e+05  284806.000000  284806.000000
# mean        0.000002  4.405008e-08       0.000002      -0.000006
# std         1.415871  1.380249e+00       1.332273       1.237092
# min        -5.683171 -1.137433e+02     -26.160506     -43.557242
# ...

# %%
nRow, nCol = a.shape

# %%
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 284806 rows and 31 columns

# %% [markdown]
# # drops duplicate rows

# %%
a.drop_duplicates(keep='first').shape
# Out:
# (283725, 31)

# %%
 a.shape
# Out:
# (284806, 31)

# %%
a.describe()
# Out:
#                 Time             V1            V2             V3  \
# count  284806.000000  284806.000000  2.848060e+05  284806.000000
# mean    94813.585781       0.000002  6.661837e-07      -0.000002
# std     47488.004530       1.958699  1.651311e+00       1.516257
# min         0.000000     -56.407510 -7.271573e+01     -48.325589
# 25%     54201.250000      -0.920374 -5.985522e-01      -0.890368
# 50%     84691.500000       0.018109  6.549621e-02       0.179846
# 75%    139320.000000       1.315645  8.037257e-01       1.027198
# max    172788.000000       2.454930  2.205773e+01       9.382558
#
#                   V4            V5             V6             V7  \
# count  284806.000000  2.848060e+05  284806.000000  284806.000000
# mean        0.000002  4.405008e-08       0.000002      -0.000006
# std         1.415871  1.380249e+00       1.332273       1.237092
# min        -5.683171 -1.137433e+02     -26.160506     -43.557242
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284806 entries, 0 to 284805
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284806 non-null  float64
#  1   V1      284806 non-null  float64
#  2   V2      284806 non-null  float64
#  3   V3      284806 non-null  float64
#  4   V4      284806 non-null  float64
#  5   V5      284806 non-null  float64
#  6   V6      284806 non-null  float64
#  7   V7      284806 non-null  float64
#  8   V8      284806 non-null  float64
#  9   V9      284806 non-null  float64
#  10  V10     284806 non-null  float64
#  11  V11     284806 non-null  float64
#  12  V12     284806 non-null  float64
#  13  V13     284806 non-null  float64
#  14  V14     284806 non-null  float64
#  15  V15     284806 non-null  float64
#  16  V16     284806 non-null  float64
#  17  V17     284806 non-null  float64
#  18  V18     284806 non-null  float64
#  19  V19     284806 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
a.hist(bins=50, figsize=(20,15))
plt.show()
# Out:
# c:\users\victoria\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\victoria\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\victoria\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# ...

# %%
corr_matrix = a.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class     1.000000
# V11       0.154876
# V4        0.133447
# V2        0.091289
# V21       0.040413
# V19       0.034783
# V20       0.020090
# V8        0.019875
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# V26       0.004455
# V25       0.003308
# V22       0.000805
# V23      -0.002685
# V15      -0.004223
# V13      -0.004570
# V24      -0.007221
# Time     -0.012322
# V6       -0.043643
# V5       -0.094974
# V9       -0.097733
# V1       -0.101347
# V18      -0.111485
# V7       -0.187257
# V3       -0.192961
# V16      -0.196539
# V10      -0.216883
# V12      -0.260593
# V14      -0.302544
# V17      -0.326482
# Name: Class, dtype: float64

# %%
Vs = a[['V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28']]
Vs[-5:]
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 284801   0.120316   0.931005 -0.546012 -0.745097  1.130314 -0.235973
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
#
#               V7        V8        V9       V10  ...       V19       V20  \
# 284801  0.812722  0.115093 -0.204064 -0.657422  ...  0.128904  0.000676
# 284802 -4.918215  7.305334  1.914428  4.356170  ... -0.682920  1.475829
# 284803  0.024330  0.294869  0.584800 -0.975926  ... -1.545556  0.059616
# 284804 -0.296827  0.708417  0.432454 -0.484782  ... -0.577252  0.001396
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  2.897849  0.127434
#
#              V21       V22       V23       V24       V25       V26       V27  \
# ...

# %%
T=a[['Time']]
A=a[['Amount']]
C=a[['Class']]

# %%
A=a.groupby('Class').size()
A
# Out:
# Class
# 0    284314
# 1       492
# dtype: int64

# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
sns.set()
fig, ax = plt.subplots()
plt.xlim(0, 1)
plt.ylim(100,300000)
sns.countplot(a['Class'])

# %%
a1=a.groupby('Class')[['V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28']].mean()
a1
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# Class
# 0      0.008260 -0.006270  0.012168 -0.007858  0.005453  0.002421  0.009631
# 1     -4.771948  3.623778 -7.033281  4.542029 -3.151225 -1.397737 -5.568731
#
#              V8        V9       V10  ...       V19       V20       V21  \
# Class                                ...
# 0     -0.000986  0.004465  0.009827  ... -0.001177 -0.000646 -0.001236
# 1      0.570636 -2.581123 -5.676883  ...  0.680659  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28
# Class
# 0     -0.000027  0.000068  0.000182 -0.000070 -0.000086 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
# [2 rows x 28 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(18, 9))
a1.plot(kind='bar',ax=ax)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
fig, ax = plt.subplots(1, 1, figsize=(16, 10))
a1.plot(ax=ax)
plt.show()

# %%
Vs = a[['V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28']]
Vs=Vs.mean()
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
fig, ax = plt.subplots(1, 1, figsize=(16, 4))
Vs.plot(kind='bar', ax=ax)

# %%
Vs = a[['V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28']]
T=a[['Time']]
A=a[['Amount']]
C=a[['Class']]
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
x = Vs
y1, y2,y3 = T, A, C
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(x, y1)
axes[0].set_title("Time verses Vs")
axes[0].set_xlabel("Vs", fontsize=10)
axes[0].set_ylabel("Time", fontsize=10)
axes[1].plot(x, y2)
axes[1].set_title("Amount verses Vs")
axes[1].set_xlabel("Vs", fontsize=10)
axes[1].set_ylabel("Amount", fontsize=10)
axes[2].plot(x, y3)
axes[2].set_title("Class verses Vs")
axes[2].set_xlabel("Vs", fontsize=10)
axes[2].set_ylabel("Class", fontsize=10)
# Out:
# Text(0, 0.5, 'Class')

# %% [markdown]
# # Statistical modelling

# %%
# Statistical modelling and Prediction through Statsmodel.
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
model = smf.logit("Class ~ Amount + Time",a )
result = model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.012630
#          Iterations 11
#                            Logit Regression Results
# ...
# Dep. Variable:                  Class   No. Observations:               284806
# Model:                          Logit   Df Residuals:                   284803
# Method:                           MLE   Df Model:                            2
# Date:                Fri, 26 Mar 2021   Pseudo R-squ.:                0.006627
# Time:                        18:34:14   Log-Likelihood:                -3597.2
# converged:                       True   LL-Null:                       -3621.2
# Covariance Type:            nonrobust   LLR p-value:                 3.780e-11
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.8239      0.091    -64.095      0.000      -6.002      -5.646
# ...

# %%
print(result.get_margeff().summary())
# Out:
#         Logit Marginal Effects
# ...
# Dep. Variable:                  Class
# Method:                          dydx
# At:                           overall
# ...
#                 dy/dx    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Amount      3.555e-07   1.18e-07      3.004      0.003    1.24e-07    5.87e-07
# Time       -1.093e-08   1.75e-09     -6.254      0.000   -1.43e-08    -7.5e-09
# ...

# %%
z, p = stats.normaltest(result.fittedvalues.values)
p
# Out:
# 0.0

# %% [markdown]
# # Pre-processing

# %%
# Machine learning
# features Class, Amount and Time
X = a.iloc[:, [0, 29]].values
y = a.iloc[:, 30].values
X[:4]
# Out:
# array([[  0.  , 149.62],
#        [  0.  ,   2.69],
#        [  1.  , 378.66],
#        [  1.  , 123.5 ]])

# %%
X.shape
# Out:
# (284806, 2)

# %%
y[:4]
# Out:
# array([0, 0, 0, 0], dtype=int64)

# %%
y.shape
# Out:
# (284806,)

# %%
# Train dataset virtualization
plt.figure(figsize=(6, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], color='g', label='0')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], color='y', label='1')
plt.legend();

# %% [markdown]
# # Splitting the train_test

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Build Classification models and Evaluate

# %%
# The followings are some important ML classification algorithms:
#Logistic Regression
# Support Vector Machine (SVM)
# Decision Tree
# Naïve Bayes
# Random Forest
# Stochastic Gradient Descent(SGD) classifier,
#KNeighborsClassifier

# %%
# Logistic Regression 
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0,solver='saga',multi_class='auto')
classifier.fit(X_train, y_train)
Clpred=classifier.predict(X_test)
Clpred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
def Cl_Matrix(y_test,Xpred):
    print ('Classification Report : ',classification_report(y_test,Xpred))
    print ('Confusion Matrix :',confusion_matrix(y_test,Xpred ))
    print ('Accuracy Score is',accuracy_score(y_test,Xpred))
    print('AUC-ROC:',roc_auc_score(y_test,Xpred))
    print('LOGLOSS Value is',log_loss(y_test,Xpred))
Cl_Matrix(y_test,Clpred)
# Out:
# c:\users\victoria\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.00      0.00      0.00       102
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix : [[56860     0]
#  [  102     0]]
# Accuracy Score is 0.9982093325374811
# AUC-ROC: 0.5
# LOGLOSS Value is 0.06184746308558242

# %%
# Gaussian Naïve Bayes
from sklearn.naive_bayes import GaussianNB
GNBclf = GaussianNB()
GNBclf.fit(X_train, y_train)
GNBpred=GNBclf.predict(X_test)
GNBpred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
def Cl_Matrix(y_test,Xpred):
    print ('Classification Report : ',classification_report(y_test,Xpred))
    print ('Confusion Matrix :',confusion_matrix(y_test,Xpred ))
    print ('Accuracy Score is',accuracy_score(y_test,Xpred))
    print('AUC-ROC:',roc_auc_score(y_test,Xpred))
    print('LOGLOSS Value is',log_loss(y_test,Xpred))
Cl_Matrix(y_test,GNBpred)
# Out:
# Classification Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.00      0.00      0.00       102
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix : [[56773    87]
#  [  102     0]]
# Accuracy Score is 0.9966819985253327
# AUC-ROC: 0.49923496306718257
# LOGLOSS Value is 0.11460093226387068

# %%
# Support Vector Machine (SVM)
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
SVCpred=model.predict(X_test)
SVCpred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
def Cl_Matrix(y_test,Xpred):
    print ('Classification Report : ',classification_report(y_test,Xpred))
    print ('Confusion Matrix :',confusion_matrix(y_test,Xpred ))
    print ('Accuracy Score is',accuracy_score(y_test,Xpred))
    print('AUC-ROC:',roc_auc_score(y_test,Xpred))
    print('LOGLOSS Value is',log_loss(y_test,Xpred))
Cl_Matrix(y_test,SVCpred)
# Out:
# c:\users\victoria\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.00      0.00      0.00       102
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix : [[56860     0]
#  [  102     0]]
# Accuracy Score is 0.9982093325374811
# AUC-ROC: 0.5
# LOGLOSS Value is 0.06184746308558242

# %%
from sklearn.tree import DecisionTreeClassifier
DFclf = DecisionTreeClassifier()
DFclf = DFclf.fit(X_train,y_train)
DTpred = DFclf.predict(X_test)
DTpred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
def Cl_Matrix(y_test,Xpred):
    print ('Classification Report : ',classification_report(y_test,Xpred))
    print ('Confusion Matrix :',confusion_matrix(y_test,Xpred ))
    print ('Accuracy Score is',accuracy_score(y_test,Xpred))
    print('AUC-ROC:',roc_auc_score(y_test,Xpred))
    print('LOGLOSS Value is',log_loss(y_test,Xpred))
Cl_Matrix(y_test,DTpred)
# Out:
# Classification Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.12      0.11      0.11       102
#
#     accuracy                           1.00     56962
#    macro avg       0.56      0.55      0.56     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix : [[56776    84]
#  [   91    11]]
# Accuracy Score is 0.9969277764123451
# AUC-ROC: 0.5531829122785238
# LOGLOSS Value is 0.10611202266938594

# %%
from sklearn.ensemble import RandomForestClassifier
RFclassifier = RandomForestClassifier(n_estimators=100)
RFclassifier.fit(X_train, y_train)
RFpred= RFclassifier.predict(X_test)
RFpred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
def Cl_Matrix(y_test,Xpred):
    print ('Classification Report : ',classification_report(y_test,Xpred))
    print ('Confusion Matrix :',confusion_matrix(y_test,Xpred ))
    print ('Accuracy Score is',accuracy_score(y_test,Xpred))
    print('AUC-ROC:',roc_auc_score(y_test,Xpred))
    print('LOGLOSS Value is',log_loss(y_test,Xpred))
Cl_Matrix(y_test,RFpred)
# Out:
# Classification Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.20      0.07      0.10       102
#
#     accuracy                           1.00     56962
#    macro avg       0.60      0.53      0.55     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix : [[56832    28]
#  [   95     7]]
# Accuracy Score is 0.9978406657069625
# AUC-ROC: 0.5340675067072204
# LOGLOSS Value is 0.07458115735581819

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train)
SGDpred= sgd_clf.predict(X_test)
SGDpred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
def Cl_Matrix(y_test,Xpred):
    print ('Classification Report : ',classification_report(y_test,Xpred))
    print ('Confusion Matrix :',confusion_matrix(y_test,Xpred ))
    print ('Accuracy Score is',accuracy_score(y_test,Xpred))
    print('AUC-ROC:',roc_auc_score(y_test,Xpred))
    print('LOGLOSS Value is',log_loss(y_test,Xpred))
Cl_Matrix(y_test,SGDpred)
# Out:
# c:\users\victoria\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.00      0.00      0.00       102
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix : [[56860     0]
#  [  102     0]]
# Accuracy Score is 0.9982093325374811
# AUC-ROC: 0.5
# LOGLOSS Value is 0.06184746308558242

# %%
from sklearn.neighbors import KNeighborsClassifier
Range_k = range(1,10)
for k in Range_k:
    classifier = KNeighborsClassifier(n_neighbors=k) 
    classifier.fit(X_train, y_train) 
    KNpred = classifier.predict(X_test) 
KNpred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
def Cl_Matrix(y_test,Xpred):
    print ('Classification Report : ',classification_report(y_test,Xpred))
    print ('Confusion Matrix :',confusion_matrix(y_test,Xpred ))
    print ('Accuracy Score is',accuracy_score(y_test,Xpred))
    print('AUC-ROC:',roc_auc_score(y_test,Xpred))
    print('LOGLOSS Value is',log_loss(y_test,Xpred))
Cl_Matrix(y_test,KNpred)
# Out:
# Classification Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.00      0.00      0.00       102
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix : [[56854     6]
#  [  102     0]]
# Accuracy Score is 0.9981039991573329
# AUC-ROC: 0.4999472388322195
# LOGLOSS Value is 0.06548563337374025

# %% [markdown]
# # From the above Models, it was discovered that Decision Tree Classifier is the best model for this Data analysis

# %%
Xnew=[[4.2,6.7]]
Xnew=sc.fit_transform(Xnew)
Xnew=DFclf.predict(Xnew)
Xnew
# Out:
# array([0], dtype=int64)
